# %%
# %matplotlib inline
import pandas as pd
# Out:
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                     title  year     name   type                character     n
# 0         Suuri illusioni  1985   Homo $  actor                   Guests  22.0
# 1     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan  10.0
# 2    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan   NaN
# 3              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron   NaN
# 4  Straight Outta Compton  2015  $hutter  actor              Club Patron   NaN

# %%
release_dates = pd.DataFrame.from_csv('data/release_dates.csv', index_col=None,
                                      parse_dates=['date'], infer_datetime_format=True)
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4                 #Horror  2015           UK 2016-05-16

# %% [markdown]
# ### Make a bar plot of the months in which movies with "Christmas" in their title tend to be released in the USA.

# %%
r = release_dates
r = r[r.title.str.contains('Christmas') & (r.country == 'USA')]
r.groupby([r.date.dt.month]).size().plot(kind='bar')

# %% [markdown]
# ### Make a bar plot of the months in which movies whose titles start with "The Hobbit" are released in the USA.

# %%
r = release_dates
r = r[r.title.str.startswith('The Hobbit') & (r.country == 'USA')]
r.date.dt.month.value_counts().sort_index().plot(kind='bar')
#r.groupby([r.date.dt.month]).size().plot(kind='bar')

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA.

# %%
r = release_dates
r = r[r.title.str.contains('Romance') & (r.country == 'USA')]
r.groupby([r.date.dt.dayofweek]).size().plot(kind='bar')

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Action" in their title tend to be released in the USA.

# %%
r = release_dates
r = r[r.title.str.contains('Action') & (r.country == 'USA')]
r.groupby([r.date.dt.dayofweek]).size().plot(kind='bar')

# %% [markdown]
# ### On which date was each Judi Dench movie from the 1990s released in the USA?

# %%
c = cast
c = c[(c.name == "Judi Dench") & (c.year // 10 == 199)]
usa = release_dates[release_dates.country == 'USA']
c.merge(usa).sort('date')
# Out:
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                      title  year        name     type        character     n  \
# 0                GoldenEye  1995  Judi Dench  actress                M   6.0
# 2             Jack & Sarah  1995  Judi Dench  actress         Margaret   3.0
# 1                   Hamlet  1996  Judi Dench  actress           Hecuba  12.0
# 3                Mrs Brown  1997  Judi Dench  actress   Queen Victoria   1.0
# 7      Tomorrow Never Dies  1997  Judi Dench  actress                M   9.0
# 4      Shakespeare in Love  1998  Judi Dench  actress  Queen Elizabeth  12.0
# 5       Tea with Mussolini  1999  Judi Dench  actress         Arabella   2.0
# 6  The World Is Not Enough  1999  Judi Dench  actress                M   6.0
#
#   country       date
# 0     USA 1995-11-17
# 2     USA 1996-03-22
# 1     USA 1996-12-25
# 3     USA 1997-10-03
# 7     USA 1997-12-19
# 4     USA 1999-01-08
# 5     USA 1999-05-14
# 6     USA 1999-11-19

# %% [markdown]
# ### In which months do films with Judi Dench tend to be released in the USA?

# %%
c = cast
c = c[(c.name == "Judi Dench")]
usa = release_dates[release_dates.country == 'USA']
m = c.merge(usa).sort('date')
m.date.dt.month.value_counts().sort_index().plot(kind='bar')
# Out:
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %% [markdown]
# ### In which months do films with Tom Cruise tend to be released in the USA?

# %%
c = cast
c = c[(c.name == "Tom Cruise")]
usa = release_dates[release_dates.country == 'USA']
m = c.merge(usa).sort('date')
m.date.dt.month.value_counts().sort_index().plot(kind='bar')
# Out:
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
r = release_dates
r.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4                 #Horror  2015           UK 2016-05-16

# %%
r.date.dt.month
# Out:
# 0          6
# 1          1
# 2          1
# 3         11
# 4          5
# 5          9
# 6          2
# 7          7
# 8          3
# 9         10
# 10         7
# 11        10
# 12         5
# 13        12
# 14        11
# 15        12
# 16         2
# 17         3
# 18         3
# 19         5
# 20         9
# 21         9
# 22        10
# 23        10
# 24         1
# 25        11
# 26         5
# 27        10
# 28         5
# 29         1
#           ..
# 437082     4
# 437083     4
# 437084     4
# 437085     4
# 437086     4
# 437087     4
# 437088     4
# 437089     4
# 437090     4
# 437091     4
# 437092     4
# 437093     4
# 437094     4
# 437095     4
# 437096     4
# 437097     4
# 437098     4
# 437099     6
# 437100     6
# 437101     6
# 437102     6
# 437103     1
# 437104     1
# 437105     1
# 437106     1
# 437107     1
# 437108     1
# 437109     1
# 437110     2
# 437111     2
# Name: date, dtype: int64

# %%
#merge

c = cast
c = c[c.name == 'Ellen Page']
c.merge(release_dates)
# Out:
#                      title  year        name     type      character     n  \
# 0        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 1        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 2        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 3        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 4        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 5        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 6        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 7        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 8        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 9                 Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 10                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 11                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 12                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 13                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 14                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 15                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 16                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 17                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 18                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 19                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 20                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 21                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 22                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 23                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 24                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 25                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 26                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 27                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 28                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# 29                Freeheld  2015  Ellen Page  actress  Stacie Andree   2.0
# ..                     ...   ...         ...      ...            ...   ...
# 436  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 437  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 438  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 439  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 440  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 441  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 442  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 443  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 444  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 445  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 446  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 447  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 448  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 449  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 450  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 451  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 452  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 453  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 454  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 455  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 456  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 457  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 458  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 459  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 460  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 461  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 462  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 463  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 464  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
# 465  X-Men: The Last Stand  2006  Ellen Page  actress      Shadowcat  13.0
#
#                    country       date
# 0                   Sweden 2007-12-07
# 1                   Greece 2008-05-15
# 2                    Spain 2008-06-13
# 3                  Finland 2008-07-18
# 4                   Mexico 2008-08-08
# 5                   Brazil 2008-08-22
# 6                   Panama 2008-11-14
# 7                 Colombia 2009-10-16
# 8                     Peru 2010-03-18
# 9                    Italy 2015-11-05
# 10                  Israel 2015-12-03
# 11               Hong Kong 2015-12-05
# 12                  France 2016-02-10
# 13                 Ireland 2016-02-19
# 14                  Taiwan 2016-02-19
# 15                      UK 2016-02-19
# 16                  Mexico 2016-03-04
# 17                Portugal 2016-03-24
# 18               Argentina 2016-04-07
# 19                 Germany 2016-04-07
# 20                 Uruguay 2016-04-07
# 21                  Brazil 2016-04-21
# 22                   Spain 2016-05-06
# 23             Netherlands 2016-05-19
# 24                   Chile 2016-05-26
# 818450   Arsenic and Old Lace  1944  Cary Grant  actor     Mortimer Brewster
# 818451         Big Brown Eyes  1936  Cary Grant  actor  Det. Sgt. Danny Barr
# 818453         Born to Be Bad  1934  Cary Grant  actor        Malcolm Trevor
# 818454       Bringing Up Baby  1938  Cary Grant  actor                 David
#
#           n
# 818449  1.0
# 818450  1.0
# 818451  1.0
# 818453  2.0
# 818454  2.0

# %%
c = c.merge(cast, on=['title', 'year'])
c = c[c.n_y <= 2]
c = c[c.name_y != 'Cary Grant']
c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e3f3758dbd03> in <module>()
#       1 c = c.merge(cast, on=['title', 'year'])
# ----> 2 c = c[c.n_y <= 2]
#       3 c = c[c.name_y != 'Cary Grant']
#       4 c
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
# -> 1993             return self._getitem_frame(key)
#    1994         elif is_mi_columns:
#    1995             return self._getitem_multilevel(key)
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_frame(self, key)
#    2067         if key.values.size and not com.is_bool_dtype(key.values):
#    2068             raise ValueError('Must pass DataFrame with boolean values only')
# -> 2069         return self.where(key)
#    2070
#    2071     def query(self, expr, inplace=False, **kwargs):
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/generic.pyc in where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    4489                                         raise_on_error=raise_on_error,
#    4490                                         try_cast=try_cast, axis=block_axis,
# -> 4491                                         transpose=self._AXIS_REVERSED)
#    4492
#    4493             return self._constructor(new_data).__finalize__(self)
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/internals.pyc in where(self, **kwargs)
#    2906
#    2907     def where(self, **kwargs):
# -> 2908         return self.apply('where', **kwargs)
#    2909
#    2910     def eval(self, **kwargs):
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2885                     axis = getattr(obj, '_info_axis_number', 0)
#    2886                     kwargs[k] = obj.reindex_axis(b_items, axis=axis,
# -> 2887                                                  copy=align_copy)
#    2888
#    2889             kwargs['mgr'] = self
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/frame.pyc in reindex_axis(self, labels, axis, method, level, copy, limit, fill_value)
#    2747                      self).reindex_axis(labels=labels, axis=axis,
#    2748                                         method=method, level=level, copy=copy,
# -> 2749                                         limit=limit, fill_value=fill_value)
#    2750
#    2751     @Appender(_shared_docs['rename'] % _shared_doc_kwargs)
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/generic.pyc in reindex_axis(self, labels, axis, method, level, copy, limit, fill_value)
#    2316                                                  limit=limit)
#    2317         return self._reindex_with_indexers({axis: [new_index, indexer]},
# -> 2318                                            fill_value=fill_value, copy=copy)
#    2319
#    2320     def _reindex_with_indexers(self, reindexers, fill_value=np.nan, copy=False,
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/generic.pyc in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    2339                                                 fill_value=fill_value,
#    2340                                                 allow_dups=allow_dups,
# -> 2341                                                 copy=copy)
#    2342
#    2343         if copy and new_data is self._data:
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/core/internals.pyc in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3584         # some axes don't allow reindexing with dups
#    3585         if not allow_dups:
# -> 3586             self.axes[axis]._can_reindex(indexer)
#    3587
#    3588         if axis >= self.ndim:
#
# /Users/dhara/miniconda2/envs/env/lib/python2.7/site-packages/pandas/indexes/base.pyc in _can_reindex(self, indexer)
#    2291         # trying to reindex on an axis with duplicates
#    2292         if not self.is_unique and len(indexer):
# -> 2293             raise ValueError("cannot reindex from a duplicate axis")
#    2294
#    2295     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis
